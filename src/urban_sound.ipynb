# %%
import os
import time
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.metrics import confusion_matrix, classification_report,accuracy_score,average_precision_score,f1_score

import librosa
import IPython.display as ipd
import random

# %%
s, sr = librosa.load("../data//fold1/101415-3-0-2.wav")

# %%
ipd.Audio("../data/fold1/101415-3-0-2.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
df = pd.read_csv("../data/UrbanSound8K.csv")
df.head()
# Out:
#       slice_file_name    fsID  start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032    0.0   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263   58.5  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263   60.5  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263   63.0  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263   68.5  72.500000         1     5        2
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing

# %%
folder_path = "../data"

folds = os.listdir(folder_path)
print(folds)
# Out:
# ['fold1', 'fold10', 'fold2', 'fold3', 'fold4', 'fold5', 'fold6', 'fold7', 'fold8', 'fold9', 'UrbanSound8K.csv']

# %%
fold_paths = [f"{folder_path}/{i}" for i in folds]

fold_paths
# Out:
# ['../data/fold1',
#  '../data/fold10',
#  '../data/fold2',
#  '../data/fold3',
#  '../data/fold4',
#  '../data/fold5',
#  '../data/fold6',
#  '../data/fold7',
#  '../data/fold8',
#  '../data/fold9',
#  '../data/UrbanSound8K.csv']

# %%
# Shuffling the folder paths inorder to aviod biased loeading of data
random.shuffle(fold_paths)
fold_paths
# Out:
# ['../data/fold6',
#  '../data/fold4',
#  '../data/fold8',
#  '../data/fold2',
#  '../data/fold3',
#  '../data/fold5',
#  '../data/fold7',
#  '../data/fold9',
#  '../data/UrbanSound8K.csv',
#  '../data/fold1',
#  '../data/fold10']

# %% [markdown]
# ## Extracting the training data and testing data paths

# %%
#Training Data Paths
s = time.time()
train_data_paths = []

for i in range(9):
    
    curr_folder_path = fold_paths[i]
    
    if (curr_folder_path == "../data/UrbanSound8K.csv"):
        continue
    
    curr_files = os.listdir(curr_folder_path)
    
    file_paths = [os.path.join(curr_folder_path, file) for file in curr_files]
    
    for j in range(len(file_paths)):
        curr_file = curr_files[j]
        class_id = df[df['slice_file_name'] == curr_file]
        arr = np.array(class_id['classID'])

        train_data_paths.append([file_paths[j], arr[0]])
        
        
e = time.time()
print((e-s)/60, " mins")
print(len(train_data_paths))
print (train_data_paths[9][0])

ipd.Audio(train_data_paths[9][0])
# Out:
# 0.13983993927637736  mins
# 7022
# ../data/fold6\104327-2-0-34.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
s = time.time()

test_data_paths = []
for i in range(9,11):
    
    curr_folder_path = fold_paths[i]
    
    if (curr_folder_path == "../input/urbansound8k/UrbanSound8K.csv"):
        continue
    
    curr_files = os.listdir(curr_folder_path)
    
    file_paths = [os.path.join(curr_folder_path, file) for file in curr_files]
    
    for j in range(len(file_paths)):
        curr_file = curr_files[j]
        class_id = df[df['slice_file_name'] == curr_file]
        arr = np.array(class_id['classID'])

        test_data_paths.append([file_paths[j], arr[0]])
        
      
e = time.time()
print((e-s)/60, " mins")
print(len(test_data_paths))
test_data_paths
# Out:
# 0.034167627493540444  mins
# 1710
# [['../data/fold1\\101415-3-0-2.wav', 3],
#  ['../data/fold1\\101415-3-0-3.wav', 3],
#  ['../data/fold1\\101415-3-0-8.wav', 3],
#  ['../data/fold1\\102106-3-0-0.wav', 3],
#  ['../data/fold1\\102305-6-0-0.wav', 6],
#  ['../data/fold1\\102842-3-0-1.wav', 3],
#  ['../data/fold1\\102842-3-1-0.wav', 3],
#  ['../data/fold1\\102842-3-1-5.wav', 3],
#  ['../data/fold1\\102842-3-1-6.wav', 3],
#  ['../data/fold1\\103074-7-0-0.wav', 7],
#  ['../data/fold1\\103074-7-0-1.wav', 7],
#  ['../data/fold1\\103074-7-0-2.wav', 7],
#  ['../data/fold1\\103074-7-1-0.wav', 7],
#  ['../data/fold1\\103074-7-1-1.wav', 7],
#  ['../data/fold1\\103074-7-1-2.wav', 7],
#  ['../data/fold1\\103074-7-1-3.wav', 7],
#  ['../data/fold1\\103074-7-1-4.wav', 7],
#  ['../data/fold1\\103074-7-1-5.wav', 7],
#  ['../data/fold1\\103074-7-1-6.wav', 7],
#  ['../data/fold1\\103074-7-2-0.wav', 7],
#  ['../data/fold1\\103074-7-3-0.wav', 7],
#  ['../data/fold1\\103074-7-3-1.wav', 7],
#  ['../data/fold1\\103074-7-3-2.wav', 7],
#  ['../data/fold1\\103074-7-3-3.wav', 7],
#  ['../data/fold1\\103074-7-4-0.wav', 7],
#  ['../data/fold1\\103074-7-4-1.wav', 7],
#  ['../data/fold1\\103074-7-4-2.wav', 7],
#  ['../data/fold1\\103074-7-4-3.wav', 7],
#  ['../data/fold1\\103074-7-4-4.wav', 7],
#  ['../data/fold1\\103074-7-4-5.wav', 7],
#  ['../data/fold1\\103074-7-4-6.wav', 7],
#  ['../data/fold1\\103258-5-0-0.wav', 5],
#  ['../data/fold1\\103258-5-0-1.wav', 5],
#  ['../data/fold1\\103258-5-0-10.wav', 5],
#  ['../data/fold1\\103258-5-0-11.wav', 5],
#  ['../data/fold1\\103258-5-0-12.wav', 5],
#  ['../data/fold1\\103258-5-0-13.wav', 5],
#  ['../data/fold1\\103258-5-0-14.wav', 5],
#  ['../data/fold1\\103258-5-0-15.wav', 5],
#  ['../data/fold1\\103258-5-0-16.wav', 5],
#  ['../data/fold1\\103258-5-0-17.wav', 5],
#  ['../data/fold1\\103258-5-0-18.wav', 5],
#  ['../data/fold1\\103258-5-0-19.wav', 5],
#  ['../data/fold1\\103258-5-0-2.wav', 5],
#  ['../data/fold1\\103258-5-0-3.wav', 5],
#  ['../data/fold1\\103258-5-0-4.wav', 5],
#  ['../data/fold1\\103258-5-0-5.wav', 5],
#  ['../data/fold1\\103258-5-0-6.wav', 5],
#  ['../data/fold1\\103258-5-0-7.wav', 5],
#  ['../data/fold1\\103258-5-0-8.wav', 5],
#  ['../data/fold1\\103258-5-0-9.wav', 5],
#  ['../data/fold1\\105415-2-0-1.wav', 2],
#  ['../data/fold1\\105415-2-0-15.wav', 2],
#  ['../data/fold1\\105415-2-0-19.wav', 2],
#  ['../data/fold1\\105415-2-0-21.wav', 2],
#  ['../data/fold1\\105415-2-0-24.wav', 2],
#  ['../data/fold1\\105415-2-0-4.wav', 2],
#  ['../data/fold1\\105415-2-0-6.wav', 2],
#  ['../data/fold1\\105415-2-0-8.wav', 2],
#  ['../data/fold1\\106905-8-0-0.wav', 8],
#  ['../data/fold1\\106905-8-0-1.wav', 8],
#  ['../data/fold1\\106905-8-0-2.wav', 8],
#  ['../data/fold1\\106905-8-0-3.wav', 8],
#  ['../data/fold1\\108041-9-0-11.wav', 9],
#  ['../data/fold1\\108041-9-0-2.wav', 9],
#  ['../data/fold1\\108041-9-0-4.wav', 9],
#  ['../data/fold1\\108041-9-0-5.wav', 9],
#  ['../data/fold1\\108041-9-0-6.wav', 9],
#  ['../data/fold1\\108041-9-0-7.wav', 9],
#  ['../data/fold1\\108041-9-0-9.wav', 9],
#  ['../data/fold1\\108362-2-0-11.wav', 2],
#  ['../data/fold1\\108362-2-0-12.wav', 2],
#  ['../data/fold1\\108362-2-0-21.wav', 2],
#  ['../data/fold1\\108362-2-0-23.wav', 2],
#  ['../data/fold1\\108362-2-0-29.wav', 2],
#  ['../data/fold1\\108362-2-0-30.wav', 2],
#  ['../data/fold1\\108362-2-0-7.wav', 2],
#  ['../data/fold1\\108362-2-0-9.wav', 2],
#  ['../data/fold1\\113205-5-0-0.wav', 5],
#  ['../data/fold1\\113205-5-1-0.wav', 5],
#  ['../data/fold1\\113205-5-1-1.wav', 5],
#  ['../data/fold1\\113205-5-1-2.wav', 5],
#  ['../data/fold1\\113205-5-1-3.wav', 5],
#  ['../data/fold1\\113205-5-1-4.wav', 5],
#  ['../data/fold1\\113205-5-1-5.wav', 5],
#  ['../data/fold1\\113205-5-1-6.wav', 5],
#  ['../data/fold1\\113205-5-1-7.wav', 5],
#  ['../data/fold1\\113205-5-1-8.wav', 5],
#  ['../data/fold1\\113205-5-1-9.wav', 5],
#  ['../data/fold1\\114587-3-0-2.wav', 3],
#  ['../data/fold1\\114587-3-0-4.wav', 3],
#  ['../data/fold1\\114587-3-0-5.wav', 3],
#  ['../data/fold1\\114587-3-0-7.wav', 3],
#  ['../data/fold1\\118101-3-0-0.wav', 3],
#  ['../data/fold1\\118101-3-0-3.wav', 3],
#  ['../data/fold1\\118101-3-0-4.wav', 3],
#  ['../data/fold1\\118101-3-0-6.wav', 3],
#  ['../data/fold1\\118279-8-0-0.wav', 8],
#  ['../data/fold1\\118279-8-0-1.wav', 8],
#  ['../data/fold1\\118279-8-0-10.wav', 8],
#  ['../data/fold1\\118279-8-0-11.wav', 8],
#  ['../data/fold1\\118279-8-0-12.wav', 8],
#  ['../data/fold1\\118279-8-0-13.wav', 8],
#  ['../data/fold1\\118279-8-0-14.wav', 8],
#  ['../data/fold1\\118279-8-0-2.wav', 8],
#  ['../data/fold1\\118279-8-0-3.wav', 8],
#  ['../data/fold1\\118279-8-0-4.wav', 8],
#  ['../data/fold1\\118279-8-0-5.wav', 8],
#  ['../data/fold1\\118279-8-0-6.wav', 8],
#  ['../data/fold1\\118279-8-0-7.wav', 8],
#  ['../data/fold1\\118279-8-0-8.wav', 8],
#  ['../data/fold1\\118279-8-0-9.wav', 8],
#  ['../data/fold1\\118963-3-0-0.wav', 3],
#  ['../data/fold1\\119455-5-0-0.wav', 5],
#  ['../data/fold1\\119455-5-0-1.wav', 5],
#  ['../data/fold1\\119455-5-0-2.wav', 5],
#  ['../data/fold1\\119455-5-0-3.wav', 5],
#  ['../data/fold1\\119455-5-0-4.wav', 5],
#  ['../data/fold1\\119455-5-0-5.wav', 5],
#  ['../data/fold1\\119455-5-0-6.wav', 5],
#  ['../data/fold1\\119455-5-0-7.wav', 5],
#  ['../data/fold1\\122690-6-0-0.wav', 6],
#  ['../data/fold1\\124489-9-0-12.wav', 9],
#  ['../data/fold1\\124489-9-0-14.wav', 9],
#  ['../data/fold1\\124489-9-0-16.wav', 9],
#  ['../data/fold1\\124489-9-0-17.wav', 9],
#  ['../data/fold1\\124489-9-0-18.wav', 9],
#  ['../data/fold1\\124489-9-0-6.wav', 9],
#  ['../data/fold1\\125791-3-0-12.wav', 3],
#  ['../data/fold1\\125791-3-0-13.wav', 3],
#  ['../data/fold1\\125791-3-0-15.wav', 3],
#  ['../data/fold1\\125791-3-0-9.wav', 3],
#  ['../data/fold1\\127873-0-0-0.wav', 0],
#  ['../data/fold1\\130030-3-0-0.wav', 3],
#  ['../data/fold1\\132016-9-0-0.wav', 9],
#  ['../data/fold1\\132016-9-0-11.wav', 9],
#  ['../data/fold1\\132016-9-0-14.wav', 9],
#  ['../data/fold1\\132016-9-0-16.wav', 9],
#  ['../data/fold1\\132016-9-0-20.wav', 9],
#  ['../data/fold1\\132016-9-0-6.wav', 9],
#  ['../data/fold1\\134717-0-0-0.wav', 0],
#  ['../data/fold1\\134717-0-0-1.wav', 0],
#  ['../data/fold1\\134717-0-0-12.wav', 0],
#  ['../data/fold1\\134717-0-0-13.wav', 0],
#  ['../data/fold1\\134717-0-0-14.wav', 0],
#  ['../data/fold1\\134717-0-0-15.wav', 0],
#  ['../data/fold1\\134717-0-0-16.wav', 0],
#  ['../data/fold1\\134717-0-0-18.wav', 0],
#  ['../data/fold1\\134717-0-0-19.wav', 0],
#  ['../data/fold1\\134717-0-0-2.wav', 0],
#  ['../data/fold1\\134717-0-0-20.wav', 0],
#  ['../data/fold1\\134717-0-0-21.wav', 0],
#  ['../data/fold1\\134717-0-0-22.wav', 0],
#  ['../data/fold1\\134717-0-0-23.wav', 0],
#  ['../data/fold1\\134717-0-0-24.wav', 0],
#  ['../data/fold1\\134717-0-0-25.wav', 0],
#  ['../data/fold1\\134717-0-0-26.wav', 0],
#  ['../data/fold1\\134717-0-0-27.wav', 0],
#  ['../data/fold1\\134717-0-0-28.wav', 0],
#  ['../data/fold1\\134717-0-0-4.wav', 0],
#  ['../data/fold1\\134717-0-0-5.wav', 0],
#  ['../data/fold1\\134717-0-0-6.wav', 0],
#  ['../data/fold1\\134717-0-0-7.wav', 0],
#  ['../data/fold1\\134717-0-0-8.wav', 0],
#  ['../data/fold1\\134717-0-0-9.wav', 0],
#  ['../data/fold1\\135776-2-0-32.wav', 2],
#  ['../data/fold1\\135776-2-0-37.wav', 2],
#  ['../data/fold1\\135776-2-0-40.wav', 2],
#  ['../data/fold1\\135776-2-0-49.wav', 2],
#  ['../data/fold1\\135776-2-0-50.wav', 2],
#  ['../data/fold1\\135776-2-0-65.wav', 2],
#  ['../data/fold1\\135776-2-0-85.wav', 2],
#  ['../data/fold1\\135776-2-0-90.wav', 2],
#  ['../data/fold1\\137156-9-0-28.wav', 9],
#  ['../data/fold1\\137156-9-0-30.wav', 9],
#  ['../data/fold1\\137156-9-0-31.wav', 9],
#  ['../data/fold1\\137156-9-0-5.wav', 9],
#  ['../data/fold1\\137156-9-0-73.wav', 9],
#  ['../data/fold1\\137156-9-0-79.wav', 9],
#  ['../data/fold1\\138015-3-0-1.wav', 3],
#  ['../data/fold1\\138015-3-0-5.wav', 3],
#  ['../data/fold1\\138015-3-0-7.wav', 3],
#  ['../data/fold1\\138031-2-0-13.wav', 2],
#  ['../data/fold1\\138031-2-0-2.wav', 2],
#  ['../data/fold1\\138031-2-0-22.wav', 2],
#  ['../data/fold1\\138031-2-0-23.wav', 2],
#  ['../data/fold1\\138031-2-0-28.wav', 2],
#  ['../data/fold1\\138031-2-0-45.wav', 2],
#  ['../data/fold1\\138031-2-0-47.wav', 2],
#  ['../data/fold1\\138031-2-0-7.wav', 2],
#  ['../data/fold1\\139951-9-0-13.wav', 9],
#  ['../data/fold1\\139951-9-0-17.wav', 9],
#  ['../data/fold1\\139951-9-0-29.wav', 9],
#  ['../data/fold1\\139951-9-0-33.wav', 9],
#  ['../data/fold1\\139951-9-0-45.wav', 9],
#  ['../data/fold1\\139951-9-0-9.wav', 9],
#  ['../data/fold1\\14113-4-0-0.wav', 4],
#  ['../data/fold1\\14113-4-0-1.wav', 4],
#  ['../data/fold1\\143604-5-0-0.wav', 5],
#  ['../data/fold1\\143651-2-0-0.wav', 2],
#  ['../data/fold1\\143651-2-0-16.wav', 2],
#  ['../data/fold1\\143651-2-0-20.wav', 2],
#  ['../data/fold1\\143651-2-0-22.wav', 2],
#  ['../data/fold1\\143651-2-0-39.wav', 2],
#  ['../data/fold1\\143651-2-0-55.wav', 2],
#  ['../data/fold1\\143651-2-0-59.wav', 2],
#  ['../data/fold1\\143651-2-0-63.wav', 2],
#  ['../data/fold1\\146186-5-0-0.wav', 5],
#  ['../data/fold1\\146186-5-0-1.wav', 5],
#  ['../data/fold1\\146186-5-0-10.wav', 5],
#  ['../data/fold1\\146186-5-0-11.wav', 5],
#  ['../data/fold1\\146186-5-0-12.wav', 5],
#  ['../data/fold1\\146186-5-0-13.wav', 5],
#  ['../data/fold1\\146186-5-0-2.wav', 5],
#  ['../data/fold1\\146186-5-0-3.wav', 5],
#  ['../data/fold1\\146186-5-0-4.wav', 5],
#  ['../data/fold1\\146186-5-0-5.wav', 5],
#  ['../data/fold1\\146186-5-0-6.wav', 5],
#  ['../data/fold1\\146186-5-0-7.wav', 5],
#  ['../data/fold1\\146186-5-0-8.wav', 5],
#  ['../data/fold1\\146186-5-0-9.wav', 5],
#  ['../data/fold1\\147764-4-0-0.wav', 4],
#  ['../data/fold1\\147764-4-1-0.wav', 4],
#  ['../data/fold1\\147764-4-2-0.wav', 4],
#  ['../data/fold1\\147764-4-3-0.wav', 4],
#  ['../data/fold1\\147764-4-4-0.wav', 4],
#  ['../data/fold1\\147764-4-4-1.wav', 4],
#  ['../data/fold1\\147764-4-4-2.wav', 4],
#  ['../data/fold1\\147764-4-5-0.wav', 4],
#  ['../data/fold1\\147764-4-6-0.wav', 4],
#  ['../data/fold1\\147764-4-7-0.wav', 4],
#  ['../data/fold1\\147764-4-8-0.wav', 4],
#  ['../data/fold1\\150341-3-0-0.wav', 3],
#  ['../data/fold1\\150341-3-1-0.wav', 3],
#  ['../data/fold1\\151977-0-0-0.wav', 0],
#  ['../data/fold1\\151977-0-0-1.wav', 0],
#  ['../data/fold1\\151977-0-0-10.wav', 0],
#  ['../data/fold1\\151977-0-0-11.wav', 0],
#  ['../data/fold1\\151977-0-0-12.wav', 0],
#  ['../data/fold1\\151977-0-0-13.wav', 0],
#  ['../data/fold1\\151977-0-0-2.wav', 0],
#  ['../data/fold1\\151977-0-0-3.wav', 0],
#  ['../data/fold1\\151977-0-0-4.wav', 0],
#  ['../data/fold1\\151977-0-0-5.wav', 0],
#  ['../data/fold1\\151977-0-0-6.wav', 0],
#  ['../data/fold1\\151977-0-0-7.wav', 0],
#  ['../data/fold1\\151977-0-0-8.wav', 0],
#  ['../data/fold1\\151977-0-0-9.wav', 0],
#  ['../data/fold1\\155202-9-0-124.wav', 9],
#  ['../data/fold1\\155202-9-0-126.wav', 9],
#  ['../data/fold1\\155202-9-0-135.wav', 9],
#  ['../data/fold1\\155202-9-0-38.wav', 9],
#  ['../data/fold1\\155202-9-0-42.wav', 9],
#  ['../data/fold1\\155202-9-0-6.wav', 9],
#  ['../data/fold1\\155310-3-0-0.wav', 3],
#  ['../data/fold1\\15564-2-0-0.wav', 2],
#  ['../data/fold1\\15564-2-0-1.wav', 2],
#  ['../data/fold1\\15564-2-0-2.wav', 2],
#  ['../data/fold1\\156194-1-0-0.wav', 1],
#  ['../data/fold1\\157867-8-0-0.wav', 8],
#  ['../data/fold1\\157867-8-0-1.wav', 8],
#  ['../data/fold1\\157867-8-0-10.wav', 8],
#  ['../data/fold1\\157867-8-0-11.wav', 8],
#  ['../data/fold1\\157867-8-0-12.wav', 8],
#  ['../data/fold1\\157867-8-0-13.wav', 8],
#  ['../data/fold1\\157867-8-0-14.wav', 8],
#  ['../data/fold1\\157867-8-0-15.wav', 8],
#  ['../data/fold1\\157867-8-0-16.wav', 8],
#  ['../data/fold1\\157867-8-0-17.wav', 8],
#  ['../data/fold1\\157867-8-0-18.wav', 8],
#  ['../data/fold1\\157867-8-0-19.wav', 8],
#  ['../data/fold1\\157867-8-0-2.wav', 8],
#  ['../data/fold1\\157867-8-0-20.wav', 8],
#  ['../data/fold1\\157867-8-0-21.wav', 8],
#  ['../data/fold1\\157867-8-0-22.wav', 8],
#  ['../data/fold1\\157867-8-0-23.wav', 8],
#  ['../data/fold1\\157867-8-0-24.wav', 8],
#  ['../data/fold1\\157867-8-0-25.wav', 8],
#  ['../data/fold1\\157867-8-0-26.wav', 8],
#  ['../data/fold1\\157867-8-0-27.wav', 8],
#  ['../data/fold1\\157867-8-0-28.wav', 8],
#  ['../data/fold1\\157867-8-0-3.wav', 8],
#  ['../data/fold1\\157867-8-0-4.wav', 8],
#  ['../data/fold1\\157867-8-0-5.wav', 8],
#  ['../data/fold1\\157867-8-0-6.wav', 8],
#  ['../data/fold1\\157867-8-0-7.wav', 8],
#  ['../data/fold1\\157867-8-0-8.wav', 8],
#  ['../data/fold1\\157867-8-0-9.wav', 8],
#  ['../data/fold1\\159738-8-0-0.wav', 8],
#  ['../data/fold1\\159738-8-0-1.wav', 8],
#  ['../data/fold1\\159738-8-0-10.wav', 8],
#  ['../data/fold1\\159738-8-0-11.wav', 8],
#  ['../data/fold1\\159738-8-0-12.wav', 8],
#  ['../data/fold1\\159738-8-0-13.wav', 8],
#  ['../data/fold1\\159738-8-0-14.wav', 8],
#  ['../data/fold1\\159738-8-0-15.wav', 8],
#  ['../data/fold1\\159738-8-0-16.wav', 8],
#  ['../data/fold1\\159738-8-0-17.wav', 8],
#  ['../data/fold1\\159738-8-0-18.wav', 8],
#  ['../data/fold1\\159738-8-0-19.wav', 8],
#  ['../data/fold1\\159738-8-0-2.wav', 8],
#  ['../data/fold1\\159738-8-0-3.wav', 8],
#  ['../data/fold1\\159738-8-0-4.wav', 8],
#  ['../data/fold1\\159738-8-0-5.wav', 8],
#  ['../data/fold1\\159738-8-0-6.wav', 8],
#  ['../data/fold1\\159738-8-0-7.wav', 8],
#  ['../data/fold1\\159738-8-0-8.wav', 8],
#  ['../data/fold1\\159738-8-0-9.wav', 8],
#  ['../data/fold1\\160009-2-0-1.wav', 2],
#  ['../data/fold1\\160009-2-0-11.wav', 2],
#  ['../data/fold1\\160009-2-0-22.wav', 2],
#  ['../data/fold1\\160009-2-0-30.wav', 2],
#  ['../data/fold1\\160009-2-0-31.wav', 2],
#  ['../data/fold1\\160009-2-0-47.wav', 2],
#  ['../data/fold1\\160009-2-0-5.wav', 2],
#  ['../data/fold1\\160009-2-0-50.wav', 2],
#  ['../data/fold1\\160094-3-0-0.wav', 3],
#  ['../data/fold1\\161702-9-0-26.wav', 9],
#  ['../data/fold1\\161702-9-0-30.wav', 9],
#  ['../data/fold1\\161702-9-0-37.wav', 9],
#  ['../data/fold1\\161702-9-0-45.wav', 9],
#  ['../data/fold1\\161702-9-0-6.wav', 9],
#  ['../data/fold1\\161702-9-0-8.wav', 9],
#  ['../data/fold1\\162540-1-0-0.wav', 1],
#  ['../data/fold1\\162540-1-1-0.wav', 1],
#  ['../data/fold1\\162540-1-2-0.wav', 1],
#  ['../data/fold1\\162703-1-0-0.wav', 1],
#  ['../data/fold1\\164053-8-0-0.wav', 8],
#  ['../data/fold1\\164053-8-1-0.wav', 8],
#  ['../data/fold1\\164053-8-2-0.wav', 8],
#  ['../data/fold1\\164053-8-2-1.wav', 8],
#  ['../data/fold1\\164053-8-2-2.wav', 8],
#  ['../data/fold1\\164053-8-2-3.wav', 8],
#  ['../data/fold1\\164053-8-3-0.wav', 8],
#  ['../data/fold1\\164312-3-0-0.wav', 3],
#  ['../data/fold1\\164312-3-1-0.wav', 3],
#  ['../data/fold1\\164312-3-3-0.wav', 3],
#  ['../data/fold1\\164312-3-4-0.wav', 3],
#  ['../data/fold1\\165067-2-0-111.wav', 2],
#  ['../data/fold1\\165067-2-0-112.wav', 2],
#  ['../data/fold1\\165067-2-0-35.wav', 2],
#  ['../data/fold1\\165067-2-0-56.wav', 2],
#  ['../data/fold1\\165067-2-0-72.wav', 2],
#  ['../data/fold1\\165067-2-0-9.wav', 2],
#  ['../data/fold1\\165067-2-0-91.wav', 2],
#  ['../data/fold1\\165642-4-0-0.wav', 4],
#  ['../data/fold1\\165645-4-0-0.wav', 4],
#  ['../data/fold1\\165645-4-1-0.wav', 4],
#  ['../data/fold1\\165645-4-2-0.wav', 4],
#  ['../data/fold1\\165645-4-3-0.wav', 4],
#  ['../data/fold1\\165645-4-4-0.wav', 4],
#  ['../data/fold1\\165645-4-5-0.wav', 4],
#  ['../data/fold1\\166268-3-0-0.wav', 3],
#  ['../data/fold1\\166268-3-1-0.wav', 3],
#  ['../data/fold1\\166268-3-2-0.wav', 3],
#  ['../data/fold1\\172314-9-0-22.wav', 9],
#  ['../data/fold1\\172314-9-0-40.wav', 9],
#  ['../data/fold1\\172314-9-0-51.wav', 9],
#  ['../data/fold1\\172314-9-0-52.wav', 9],
#  ['../data/fold1\\172314-9-0-72.wav', 9],
#  ['../data/fold1\\172314-9-0-80.wav', 9],
#  ['../data/fold1\\174276-7-0-0.wav', 7],
#  ['../data/fold1\\174276-7-1-0.wav', 7],
#  ['../data/fold1\\174276-7-2-0.wav', 7],
#  ['../data/fold1\\174276-7-3-0.wav', 7],
#  ['../data/fold1\\174276-7-4-0.wav', 7],
#  ['../data/fold1\\174276-7-5-0.wav', 7],
#  ['../data/fold1\\174276-7-6-0.wav', 7],
#  ['../data/fold1\\174290-6-0-0.wav', 6],
#  ['../data/fold1\\174290-6-1-0.wav', 6],
#  ['../data/fold1\\174290-6-2-0.wav', 6],
#  ['../data/fold1\\174290-6-3-0.wav', 6],
#  ['../data/fold1\\174294-6-0-0.wav', 6],
#  ['../data/fold1\\174294-6-1-0.wav', 6],
#  ['../data/fold1\\174294-6-2-0.wav', 6],
#  ['../data/fold1\\175845-1-0-0.wav', 1],
#  ['../data/fold1\\175851-1-0-0.wav', 1],
#  ['../data/fold1\\17592-5-0-0.wav', 5],
#  ['../data/fold1\\17592-5-1-0.wav', 5],
#  ['../data/fold1\\17592-5-1-1.wav', 5],
#  ['../data/fold1\\17592-5-1-2.wav', 5],
#  ['../data/fold1\\17592-5-1-3.wav', 5],
#  ['../data/fold1\\176257-3-0-0.wav', 3],
#  ['../data/fold1\\176258-3-1-12.wav', 3],
#  ['../data/fold1\\176258-3-1-13.wav', 3],
#  ['../data/fold1\\176258-3-1-18.wav', 3],
#  ['../data/fold1\\176258-3-1-2.wav', 3],
#  ['../data/fold1\\176638-1-0-0.wav', 1],
#  ['../data/fold1\\176638-1-1-0.wav', 1],
#  ['../data/fold1\\176714-2-0-18.wav', 2],
#  ['../data/fold1\\176714-2-0-23.wav', 2],
#  ['../data/fold1\\176714-2-0-26.wav', 2],
#  ['../data/fold1\\176714-2-0-33.wav', 2],
#  ['../data/fold1\\176714-2-0-40.wav', 2],
#  ['../data/fold1\\176714-2-0-51.wav', 2],
#  ['../data/fold1\\176714-2-0-55.wav', 2],
#  ['../data/fold1\\176714-2-0-77.wav', 2],
#  ['../data/fold1\\176787-5-0-0.wav', 5],
#  ['../data/fold1\\176787-5-0-1.wav', 5],
#  ['../data/fold1\\176787-5-0-10.wav', 5],
#  ['../data/fold1\\176787-5-0-11.wav', 5],
#  ['../data/fold1\\176787-5-0-12.wav', 5],
#  ['../data/fold1\\176787-5-0-13.wav', 5],
#  ['../data/fold1\\176787-5-0-14.wav', 5],
#  ['../data/fold1\\176787-5-0-15.wav', 5],
#  ['../data/fold1\\176787-5-0-16.wav', 5],
#  ['../data/fold1\\176787-5-0-17.wav', 5],
#  ['../data/fold1\\176787-5-0-18.wav', 5],
#  ['../data/fold1\\176787-5-0-19.wav', 5],
#  ['../data/fold1\\176787-5-0-2.wav', 5],
#  ['../data/fold1\\176787-5-0-20.wav', 5],
#  ['../data/fold1\\176787-5-0-21.wav', 5],
#  ['../data/fold1\\176787-5-0-22.wav', 5],
#  ['../data/fold1\\176787-5-0-23.wav', 5],
#  ['../data/fold1\\176787-5-0-24.wav', 5],
#  ['../data/fold1\\176787-5-0-25.wav', 5],
#  ['../data/fold1\\176787-5-0-26.wav', 5],
#  ['../data/fold1\\176787-5-0-27.wav', 5],
#  ['../data/fold1\\176787-5-0-28.wav', 5],
#  ['../data/fold1\\176787-5-0-29.wav', 5],
#  ['../data/fold1\\176787-5-0-3.wav', 5],
#  ['../data/fold1\\176787-5-0-30.wav', 5],
#  ['../data/fold1\\176787-5-0-4.wav', 5],
#  ['../data/fold1\\176787-5-0-5.wav', 5],
#  ['../data/fold1\\176787-5-0-6.wav', 5],
#  ['../data/fold1\\176787-5-0-7.wav', 5],
#  ['../data/fold1\\176787-5-0-8.wav', 5],
#  ['../data/fold1\\176787-5-0-9.wav', 5],
#  ['../data/fold1\\177621-0-0-0.wav', 0],
#  ['../data/fold1\\177621-0-0-100.wav', 0],
#  ['../data/fold1\\177621-0-0-104.wav', 0],
#  ['../data/fold1\\177621-0-0-105.wav', 0],
#  ['../data/fold1\\177621-0-0-109.wav', 0],
#  ['../data/fold1\\177621-0-0-117.wav', 0],
#  ['../data/fold1\\177621-0-0-120.wav', 0],
#  ['../data/fold1\\177621-0-0-126.wav', 0],
#  ['../data/fold1\\177621-0-0-127.wav', 0],
#  ['../data/fold1\\177621-0-0-128.wav', 0],
#  ['../data/fold1\\177621-0-0-145.wav', 0],
#  ['../data/fold1\\177621-0-0-147.wav', 0],
#  ['../data/fold1\\177621-0-0-2.wav', 0],
#  ['../data/fold1\\177621-0-0-27.wav', 0],
#  ['../data/fold1\\177621-0-0-31.wav', 0],
#  ['../data/fold1\\177621-0-0-35.wav', 0],
#  ['../data/fold1\\177621-0-0-46.wav', 0],
#  ['../data/fold1\\177621-0-0-47.wav', 0],
#  ['../data/fold1\\177621-0-0-48.wav', 0],
#  ['../data/fold1\\177621-0-0-54.wav', 0],
#  ['../data/fold1\\177621-0-0-57.wav', 0],
#  ['../data/fold1\\177621-0-0-80.wav', 0],
#  ['../data/fold1\\177621-0-0-88.wav', 0],
#  ['../data/fold1\\177621-0-0-91.wav', 0],
#  ['../data/fold1\\177621-0-0-93.wav', 0],
#  ['../data/fold1\\17913-4-0-0.wav', 4],
#  ['../data/fold1\\17913-4-0-1.wav', 4],
#  ['../data/fold1\\17913-4-0-2.wav', 4],
#  ['../data/fold1\\17913-4-1-0.wav', 4],
#  ['../data/fold1\\17913-4-2-0.wav', 4],
#  ['../data/fold1\\179858-1-0-0.wav', 1],
#  ['../data/fold1\\179867-1-0-0.wav', 1],
#  ['../data/fold1\\180256-3-0-0.wav', 3],
#  ['../data/fold1\\180256-3-0-1.wav', 3],
#  ['../data/fold1\\180256-3-0-2.wav', 3],
#  ['../data/fold1\\180256-3-0-3.wav', 3],
#  ['../data/fold1\\180937-7-0-0.wav', 7],
#  ['../data/fold1\\180937-7-0-1.wav', 7],
#  ['../data/fold1\\180937-7-0-2.wav', 7],
#  ['../data/fold1\\180937-7-0-4.wav', 7],
#  ['../data/fold1\\180937-7-0-5.wav', 7],
#  ['../data/fold1\\180937-7-0-6.wav', 7],
#  ['../data/fold1\\180937-7-1-0.wav', 7],
#  ['../data/fold1\\180937-7-1-1.wav', 7],
#  ['../data/fold1\\180937-7-1-10.wav', 7],
#  ['../data/fold1\\180937-7-1-11.wav', 7],
#  ['../data/fold1\\180937-7-1-12.wav', 7],
#  ['../data/fold1\\180937-7-1-13.wav', 7],
#  ['../data/fold1\\180937-7-1-14.wav', 7],
#  ['../data/fold1\\180937-7-1-15.wav', 7],
#  ['../data/fold1\\180937-7-1-2.wav', 7],
#  ['../data/fold1\\180937-7-1-3.wav', 7],
#  ['../data/fold1\\180937-7-1-4.wav', 7],
#  ['../data/fold1\\180937-7-1-5.wav', 7],
#  ['../data/fold1\\180937-7-1-6.wav', 7],
#  ['../data/fold1\\180937-7-1-7.wav', 7],
#  ['../data/fold1\\180937-7-1-8.wav', 7],
#  ['../data/fold1\\180937-7-1-9.wav', 7],
#  ['../data/fold1\\180937-7-2-0.wav', 7],
#  ['../data/fold1\\180937-7-2-1.wav', 7],
#  ['../data/fold1\\180937-7-2-10.wav', 7],
#  ['../data/fold1\\180937-7-2-2.wav', 7],
#  ['../data/fold1\\180937-7-2-3.wav', 7],
#  ['../data/fold1\\180937-7-2-4.wav', 7],
#  ['../data/fold1\\180937-7-2-5.wav', 7],
#  ['../data/fold1\\180937-7-2-6.wav', 7],
#  ['../data/fold1\\180937-7-2-7.wav', 7],
#  ['../data/fold1\\180937-7-2-8.wav', 7],
#  ['../data/fold1\\180937-7-2-9.wav', 7],
#  ['../data/fold1\\180937-7-3-0.wav', 7],
#  ['../data/fold1\\180937-7-3-1.wav', 7],
#  ['../data/fold1\\180937-7-3-10.wav', 7],
#  ['../data/fold1\\180937-7-3-11.wav', 7],
#  ['../data/fold1\\180937-7-3-12.wav', 7],
#  ['../data/fold1\\180937-7-3-13.wav', 7],
#  ['../data/fold1\\180937-7-3-14.wav', 7],
#  ['../data/fold1\\180937-7-3-15.wav', 7],
#  ['../data/fold1\\180937-7-3-17.wav', 7],
#  ['../data/fold1\\180937-7-3-18.wav', 7],
#  ['../data/fold1\\180937-7-3-19.wav', 7],
#  ['../data/fold1\\180937-7-3-2.wav', 7],
#  ['../data/fold1\\180937-7-3-20.wav', 7],
#  ['../data/fold1\\180937-7-3-21.wav', 7],
#  ['../data/fold1\\180937-7-3-22.wav', 7],
#  ['../data/fold1\\180937-7-3-23.wav', 7],
#  ['../data/fold1\\180937-7-3-24.wav', 7],
#  ['../data/fold1\\180937-7-3-26.wav', 7],
#  ['../data/fold1\\180937-7-3-27.wav', 7],
#  ['../data/fold1\\180937-7-3-28.wav', 7],
#  ['../data/fold1\\180937-7-3-29.wav', 7],
#  ['../data/fold1\\180937-7-3-3.wav', 7],
#  ['../data/fold1\\180937-7-3-30.wav', 7],
#  ['../data/fold1\\180937-7-3-31.wav', 7],
#  ['../data/fold1\\180937-7-3-32.wav', 7],
#  ['../data/fold1\\180937-7-3-33.wav', 7],
#  ['../data/fold1\\180937-7-3-4.wav', 7],
#  ['../data/fold1\\180937-7-3-5.wav', 7],
#  ['../data/fold1\\180937-7-3-6.wav', 7],
#  ['../data/fold1\\180937-7-3-7.wav', 7],
#  ['../data/fold1\\180937-7-3-8.wav', 7],
#  ['../data/fold1\\180937-7-3-9.wav', 7],
#  ['../data/fold1\\180937-7-4-0.wav', 7],
#  ['../data/fold1\\180937-7-4-10.wav', 7],
#  ['../data/fold1\\180937-7-4-11.wav', 7],
#  ['../data/fold1\\180937-7-4-12.wav', 7],
#  ['../data/fold1\\180937-7-4-13.wav', 7],
#  ['../data/fold1\\180937-7-4-14.wav', 7],
#  ['../data/fold1\\180937-7-4-2.wav', 7],
#  ['../data/fold1\\180937-7-4-3.wav', 7],
#  ['../data/fold1\\180937-7-4-4.wav', 7],
#  ['../data/fold1\\180937-7-4-5.wav', 7],
#  ['../data/fold1\\180937-7-4-6.wav', 7],
#  ['../data/fold1\\180937-7-4-7.wav', 7],
#  ['../data/fold1\\180937-7-4-8.wav', 7],
#  ['../data/fold1\\180937-7-4-9.wav', 7],
#  ['../data/fold1\\182800-2-0-0.wav', 2],
#  ['../data/fold1\\182800-2-1-0.wav', 2],
#  ['../data/fold1\\182800-2-2-0.wav', 2],
#  ['../data/fold1\\182800-2-2-1.wav', 2],
#  ['../data/fold1\\182800-2-2-2.wav', 2],
#  ['../data/fold1\\182800-2-2-3.wav', 2],
#  ['../data/fold1\\182800-2-3-0.wav', 2],
#  ['../data/fold1\\182800-2-3-1.wav', 2],
#  ['../data/fold1\\184355-1-0-0.wav', 1],
#  ['../data/fold1\\19026-1-0-0.wav', 1],
#  ['../data/fold1\\191431-9-0-26.wav', 9],
#  ['../data/fold1\\191431-9-0-30.wav', 9],
#  ['../data/fold1\\191431-9-0-61.wav', 9],
#  ['../data/fold1\\191431-9-0-66.wav', 9],
#  ['../data/fold1\\191431-9-0-73.wav', 9],
#  ['../data/fold1\\191431-9-0-8.wav', 9],
#  ['../data/fold1\\192124-2-0-0.wav', 2],
#  ['../data/fold1\\192124-2-0-11.wav', 2],
#  ['../data/fold1\\192124-2-0-12.wav', 2],
#  ['../data/fold1\\192124-2-0-15.wav', 2],
#  ['../data/fold1\\192124-2-0-3.wav', 2],
#  ['../data/fold1\\192124-2-0-4.wav', 2],
#  ['../data/fold1\\192124-2-0-5.wav', 2],
#  ['../data/fold1\\192124-2-0-7.wav', 2],
#  ['../data/fold1\\193394-3-0-10.wav', 3],
#  ['../data/fold1\\193394-3-0-11.wav', 3],
#  ['../data/fold1\\193394-3-0-4.wav', 3],
#  ['../data/fold1\\193394-3-0-7.wav', 3],
#  ['../data/fold1\\193698-2-0-112.wav', 2],
#  ['../data/fold1\\193698-2-0-113.wav', 2],
#  ['../data/fold1\\193698-2-0-114.wav', 2],
#  ['../data/fold1\\193698-2-0-140.wav', 2],
#  ['../data/fold1\\193698-2-0-42.wav', 2],
#  ['../data/fold1\\193698-2-0-58.wav', 2],
#  ['../data/fold1\\193698-2-0-64.wav', 2],
#  ['../data/fold1\\193698-2-0-89.wav', 2],
#  ['../data/fold1\\194732-9-0-126.wav', 9],
#  ['../data/fold1\\194732-9-0-163.wav', 9],
#  ['../data/fold1\\194732-9-0-171.wav', 9],
#  ['../data/fold1\\194732-9-0-175.wav', 9],
#  ['../data/fold1\\194732-9-0-191.wav', 9],
#  ['../data/fold1\\194732-9-0-41.wav', 9],
#  ['../data/fold1\\194732-9-0-95.wav', 9],
#  ['../data/fold1\\196065-2-0-0.wav', 2],
#  ['../data/fold1\\196079-2-0-0.wav', 2],
#  ['../data/fold1\\196087-2-0-0.wav', 2],
#  ['../data/fold1\\196400-6-0-0.wav', 6],
#  ['../data/fold1\\197073-3-0-0.wav', 3],
#  ['../data/fold1\\197073-3-3-0.wav', 3],
#  ['../data/fold1\\197073-3-4-3.wav', 3],
#  ['../data/fold1\\197073-3-7-0.wav', 3],
#  ['../data/fold1\\197318-6-0-0.wav', 6],
#  ['../data/fold1\\197318-6-1-0.wav', 6],
#  ['../data/fold1\\197318-6-10-0.wav', 6],
#  ['../data/fold1\\197318-6-11-0.wav', 6],
#  ['../data/fold1\\197318-6-12-0.wav', 6],
#  ['../data/fold1\\197318-6-2-0.wav', 6],
#  ['../data/fold1\\197318-6-3-0.wav', 6],
#  ['../data/fold1\\197318-6-4-0.wav', 6],
#  ['../data/fold1\\197318-6-5-0.wav', 6],
#  ['../data/fold1\\197318-6-6-0.wav', 6],
#  ['../data/fold1\\197318-6-7-0.wav', 6],
#  ['../data/fold1\\197318-6-8-0.wav', 6],
#  ['../data/fold1\\197318-6-9-0.wav', 6],
#  ['../data/fold1\\203356-3-0-0.wav', 3],
#  ['../data/fold1\\203356-3-0-1.wav', 3],
#  ['../data/fold1\\203356-3-0-2.wav', 3],
#  ['../data/fold1\\203356-3-0-3.wav', 3],
#  ['../data/fold1\\203440-3-0-0.wav', 3],
#  ['../data/fold1\\203440-3-0-1.wav', 3],
#  ['../data/fold1\\203440-3-0-5.wav', 3],
#  ['../data/fold1\\203440-3-0-6.wav', 3],
#  ['../data/fold1\\21684-9-0-12.wav', 9],
#  ['../data/fold1\\21684-9-0-25.wav', 9],
#  ['../data/fold1\\21684-9-0-30.wav', 9],
#  ['../data/fold1\\21684-9-0-39.wav', 9],
#  ['../data/fold1\\21684-9-0-5.wav', 9],
#  ['../data/fold1\\21684-9-0-50.wav', 9],
#  ['../data/fold1\\21684-9-0-7.wav', 9],
#  ['../data/fold1\\22962-4-0-0.wav', 4],
#  ['../data/fold1\\22962-4-0-1.wav', 4],
#  ['../data/fold1\\22962-4-0-2.wav', 4],
#  ['../data/fold1\\24074-1-0-0.wav', 1],
#  ['../data/fold1\\24074-1-0-1.wav', 1],
#  ['../data/fold1\\24074-1-0-10.wav', 1],
#  ['../data/fold1\\24074-1-0-11.wav', 1],
#  ['../data/fold1\\24074-1-0-12.wav', 1],
#  ['../data/fold1\\24074-1-0-13.wav', 1],
#  ['../data/fold1\\24074-1-0-2.wav', 1],
#  ['../data/fold1\\24074-1-0-3.wav', 1],
#  ['../data/fold1\\24074-1-0-4.wav', 1],
#  ['../data/fold1\\24074-1-0-5.wav', 1],
#  ['../data/fold1\\24074-1-0-6.wav', 1],
#  ['../data/fold1\\24074-1-0-7.wav', 1],
#  ['../data/fold1\\24074-1-0-8.wav', 1],
#  ['../data/fold1\\24074-1-0-9.wav', 1],
#  ['../data/fold1\\26270-9-0-19.wav', 9],
#  ['../data/fold1\\26270-9-0-23.wav', 9],
#  ['../data/fold1\\26270-9-0-3.wav', 9],
#  ['../data/fold1\\26270-9-0-30.wav', 9],
#  ['../data/fold1\\26270-9-0-32.wav', 9],
#  ['../data/fold1\\26270-9-0-35.wav', 9],
#  ['../data/fold1\\30823-8-0-0.wav', 8],
#  ['../data/fold1\\31323-3-0-1.wav', 3],
#  ['../data/fold1\\31323-3-0-2.wav', 3],
#  ['../data/fold1\\31323-3-0-20.wav', 3],
#  ['../data/fold1\\31323-3-0-22.wav', 3],
#  ['../data/fold1\\31840-3-0-0.wav', 3],
#  ['../data/fold1\\31840-3-1-0.wav', 3],
#  ['../data/fold1\\40722-8-0-0.wav', 8],
#  ['../data/fold1\\40722-8-0-1.wav', 8],
#  ['../data/fold1\\40722-8-0-2.wav', 8],
#  ['../data/fold1\\40722-8-0-3.wav', 8],
#  ['../data/fold1\\40722-8-0-4.wav', 8],
#  ['../data/fold1\\40722-8-0-5.wav', 8],
#  ['../data/fold1\\40722-8-0-6.wav', 8],
#  ['../data/fold1\\40722-8-0-7.wav', 8],
#  ['../data/fold1\\40722-8-0-8.wav', 8],
#  ['../data/fold1\\43786-3-0-0.wav', 3],
#  ['../data/fold1\\43786-3-1-0.wav', 3],
#  ['../data/fold1\\43806-8-0-0.wav', 8],
#  ['../data/fold1\\44736-5-0-0.wav', 5],
#  ['../data/fold1\\44736-5-0-1.wav', 5],
#  ['../data/fold1\\46654-6-0-0.wav', 6],
#  ['../data/fold1\\46656-6-0-0.wav', 6],
#  ['../data/fold1\\46656-6-1-0.wav', 6],
#  ['../data/fold1\\46656-6-2-0.wav', 6],
#  ['../data/fold1\\46656-6-3-0.wav', 6],
#  ['../data/fold1\\46656-6-4-0.wav', 6],
#  ['../data/fold1\\46656-6-5-0.wav', 6],
#  ['../data/fold1\\46669-4-0-0.wav', 4],
#  ['../data/fold1\\46669-4-0-10.wav', 4],
#  ['../data/fold1\\46669-4-0-2.wav', 4],
#  ['../data/fold1\\46669-4-0-24.wav', 4],
#  ['../data/fold1\\46669-4-0-26.wav', 4],
#  ['../data/fold1\\46669-4-0-3.wav', 4],
#  ['../data/fold1\\46669-4-0-30.wav', 4],
#  ['../data/fold1\\46669-4-0-31.wav', 4],
#  ['../data/fold1\\46669-4-0-32.wav', 4],
#  ['../data/fold1\\46669-4-0-33.wav', 4],
#  ['../data/fold1\\46669-4-0-35.wav', 4],
#  ['../data/fold1\\46669-4-0-36.wav', 4],
#  ['../data/fold1\\46669-4-0-37.wav', 4],
#  ['../data/fold1\\46669-4-0-39.wav', 4],
#  ['../data/fold1\\46669-4-0-4.wav', 4],
#  ['../data/fold1\\46669-4-0-45.wav', 4],
#  ['../data/fold1\\46669-4-0-48.wav', 4],
#  ['../data/fold1\\46669-4-0-49.wav', 4],
#  ['../data/fold1\\46669-4-0-54.wav', 4],
#  ['../data/fold1\\46669-4-0-61.wav', 4],
#  ['../data/fold1\\46669-4-0-63.wav', 4],
#  ['../data/fold1\\46669-4-0-8.wav', 4],
#  ['../data/fold1\\46669-4-0-9.wav', 4],
#  ['../data/fold1\\46918-5-0-0.wav', 5],
#  ['../data/fold1\\46918-5-0-1.wav', 5],
#  ['../data/fold1\\46918-5-0-2.wav', 5],
#  ['../data/fold1\\50901-0-0-0.wav', 0],
#  ['../data/fold1\\50901-0-1-0.wav', 0],
#  ['../data/fold1\\50901-0-1-1.wav', 0],
#  ['../data/fold1\\51022-3-13-0.wav', 3],
#  ['../data/fold1\\51022-3-29-0.wav', 3],
#  ['../data/fold1\\51022-3-30-4.wav', 3],
#  ['../data/fold1\\51022-3-7-0.wav', 3],
#  ['../data/fold1\\54858-3-0-0.wav', 3],
#  ['../data/fold1\\54858-3-1-2.wav', 3],
#  ['../data/fold1\\54858-3-2-0.wav', 3],
#  ['../data/fold1\\55020-4-0-0.wav', 4],
#  ['../data/fold1\\55020-4-0-1.wav', 4],
#  ['../data/fold1\\55020-4-0-10.wav', 4],
#  ['../data/fold1\\55020-4-0-11.wav', 4],
#  ['../data/fold1\\55020-4-0-12.wav', 4],
#  ['../data/fold1\\55020-4-0-13.wav', 4],
#  ['../data/fold1\\55020-4-0-14.wav', 4],
#  ['../data/fold1\\55020-4-0-2.wav', 4],
#  ['../data/fold1\\55020-4-0-3.wav', 4],
#  ['../data/fold1\\55020-4-0-4.wav', 4],
#  ['../data/fold1\\55020-4-0-5.wav', 4],
#  ['../data/fold1\\55020-4-0-6.wav', 4],
#  ['../data/fold1\\55020-4-0-7.wav', 4],
#  ['../data/fold1\\55020-4-0-8.wav', 4],
#  ['../data/fold1\\55020-4-0-9.wav', 4],
#  ['../data/fold1\\57320-0-0-0.wav', 0],
#  ['../data/fold1\\57320-0-0-10.wav', 0],
#  ['../data/fold1\\57320-0-0-11.wav', 0],
#  ['../data/fold1\\57320-0-0-13.wav', 0],
#  ['../data/fold1\\57320-0-0-15.wav', 0],
#  ['../data/fold1\\57320-0-0-21.wav', 0],
#  ['../data/fold1\\57320-0-0-22.wav', 0],
#  ['../data/fold1\\57320-0-0-24.wav', 0],
#  ['../data/fold1\\57320-0-0-27.wav', 0],
#  ['../data/fold1\\57320-0-0-31.wav', 0],
#  ['../data/fold1\\57320-0-0-32.wav', 0],
#  ['../data/fold1\\57320-0-0-33.wav', 0],
#  ['../data/fold1\\57320-0-0-34.wav', 0],
#  ['../data/fold1\\57320-0-0-36.wav', 0],
#  ['../data/fold1\\57320-0-0-37.wav', 0],
#  ['../data/fold1\\57320-0-0-38.wav', 0],
#  ['../data/fold1\\57320-0-0-39.wav', 0],
#  ['../data/fold1\\57320-0-0-4.wav', 0],
#  ['../data/fold1\\57320-0-0-42.wav', 0],
#  ['../data/fold1\\57320-0-0-45.wav', 0],
#  ['../data/fold1\\57320-0-0-5.wav', 0],
#  ['../data/fold1\\57320-0-0-6.wav', 0],
#  ['../data/fold1\\57320-0-0-7.wav', 0],
#  ['../data/fold1\\57320-0-0-9.wav', 0],
#  ['../data/fold1\\57553-3-0-0.wav', 3],
#  ['../data/fold1\\57553-3-1-0.wav', 3],
#  ['../data/fold1\\57553-3-2-0.wav', 3],
#  ['../data/fold1\\57584-4-0-0.wav', 4],
#  ['../data/fold1\\57584-4-0-1.wav', 4],
#  ['../data/fold1\\57584-4-0-2.wav', 4],
#  ['../data/fold1\\57584-4-0-3.wav', 4],
#  ['../data/fold1\\57584-4-0-4.wav', 4],
#  ['../data/fold1\\57584-4-0-5.wav', 4],
#  ['../data/fold1\\57584-4-0-6.wav', 4],
#  ['../data/fold1\\57584-4-0-7.wav', 4],
#  ['../data/fold1\\57584-4-0-8.wav', 4],
#  ['../data/fold1\\59277-0-0-0.wav', 0],
#  ['../data/fold1\\59277-0-0-1.wav', 0],
#  ['../data/fold1\\59277-0-0-2.wav', 0],
#  ['../data/fold1\\59277-0-0-3.wav', 0],
#  ['../data/fold1\\59277-0-0-4.wav', 0],
#  ['../data/fold1\\59277-0-0-5.wav', 0],
#  ['../data/fold1\\59277-0-0-6.wav', 0],
#  ['../data/fold1\\59277-0-0-7.wav', 0],
#  ['../data/fold1\\65749-3-1-12.wav', 3],
#  ['../data/fold1\\65749-3-1-14.wav', 3],
#  ['../data/fold1\\65749-3-1-24.wav', 3],
#  ['../data/fold1\\65749-3-1-9.wav', 3],
#  ['../data/fold1\\69304-9-0-0.wav', 9],
#  ['../data/fold1\\69304-9-0-12.wav', 9],
#  ['../data/fold1\\69304-9-0-14.wav', 9],
#  ['../data/fold1\\69304-9-0-15.wav', 9],
#  ['../data/fold1\\69304-9-0-6.wav', 9],
#  ['../data/fold1\\69304-9-0-7.wav', 9],
#  ['../data/fold1\\7061-6-0-0.wav', 6],
#  ['../data/fold1\\71087-4-0-0.wav', 4],
#  ['../data/fold1\\71087-4-1-0.wav', 4],
#  ['../data/fold1\\72261-3-0-17.wav', 3],
#  ['../data/fold1\\72261-3-0-23.wav', 3],
#  ['../data/fold1\\72261-3-0-27.wav', 3],
#  ['../data/fold1\\72261-3-0-6.wav', 3],
#  ['../data/fold1\\72579-3-0-0.wav', 3],
#  ['../data/fold1\\72579-3-0-2.wav', 3],
#  ['../data/fold1\\72579-3-0-3.wav', 3],
#  ['../data/fold1\\72579-3-0-4.wav', 3],
#  ['../data/fold1\\73277-9-0-0.wav', 9],
#  ['../data/fold1\\73277-9-0-16.wav', 9],
#  ['../data/fold1\\73277-9-0-17.wav', 9],
#  ['../data/fold1\\73277-9-0-19.wav', 9],
#  ['../data/fold1\\73277-9-0-24.wav', 9],
#  ['../data/fold1\\73277-9-0-28.wav', 9],
#  ['../data/fold1\\7383-3-0-0.wav', 3],
#  ['../data/fold1\\7383-3-0-1.wav', 3],
#  ['../data/fold1\\7383-3-1-0.wav', 3],
#  ['../data/fold1\\76093-6-0-0.wav', 6],
#  ['../data/fold1\\76093-6-1-0.wav', 6],
#  ['../data/fold1\\77246-6-0-0.wav', 6],
#  ['../data/fold1\\77766-9-0-0.wav', 9],
#  ['../data/fold1\\77766-9-0-3.wav', 9],
#  ['../data/fold1\\77766-9-0-4.wav', 9],
#  ['../data/fold1\\77766-9-0-5.wav', 9],
#  ['../data/fold1\\77766-9-0-6.wav', 9],
#  ['../data/fold1\\77766-9-0-7.wav', 9],
#  ['../data/fold1\\78360-4-0-0.wav', 4],
#  ['../data/fold1\\78360-4-0-1.wav', 4],
#  ['../data/fold1\\78360-4-0-11.wav', 4],
#  ['../data/fold1\\78360-4-0-12.wav', 4],
#  ['../data/fold1\\78360-4-0-14.wav', 4],
#  ['../data/fold1\\78360-4-0-15.wav', 4],
#  ['../data/fold1\\78360-4-0-16.wav', 4],
#  ['../data/fold1\\78360-4-0-17.wav', 4],
#  ['../data/fold1\\78360-4-0-18.wav', 4],
#  ['../data/fold1\\78360-4-0-19.wav', 4],
#  ['../data/fold1\\78360-4-0-2.wav', 4],
#  ['../data/fold1\\78360-4-0-20.wav', 4],
#  ['../data/fold1\\78360-4-0-21.wav', 4],
#  ['../data/fold1\\78360-4-0-22.wav', 4],
#  ['../data/fold1\\78360-4-0-23.wav', 4],
#  ['../data/fold1\\78360-4-0-3.wav', 4],
#  ['../data/fold1\\78360-4-0-4.wav', 4],
#  ['../data/fold1\\78360-4-0-5.wav', 4],
#  ['../data/fold1\\78360-4-0-6.wav', 4],
#  ['../data/fold1\\78360-4-0-7.wav', 4],
#  ['../data/fold1\\78360-4-0-8.wav', 4],
#  ['../data/fold1\\78360-4-0-9.wav', 4],
#  ['../data/fold1\\83199-9-0-0.wav', 9],
#  ['../data/fold1\\86278-6-0-0.wav', 6],
#  ['../data/fold1\\86279-3-0-0.wav', 3],
#  ['../data/fold1\\87275-1-0-0.wav', 1],
#  ['../data/fold1\\87275-1-1-0.wav', 1],
#  ['../data/fold1\\87275-1-2-0.wav', 1],
#  ['../data/fold1\\87275-1-3-0.wav', 1],
#  ['../data/fold1\\87275-1-4-0.wav', 1],
#  ['../data/fold1\\87275-1-5-0.wav', 1],
#  ['../data/fold1\\88466-7-0-0.wav', 7],
#  ['../data/fold1\\89212-3-0-0.wav', 3],
#  ['../data/fold1\\89948-5-0-0.wav', 5],
#  ['../data/fold1\\9031-3-1-0.wav', 3],
#  ['../data/fold1\\9031-3-2-0.wav', 3],
#  ['../data/fold1\\9031-3-3-0.wav', 3],
#  ['../data/fold1\\9031-3-4-0.wav', 3],
#  ['../data/fold1\\94868-1-0-0.wav', 1],
#  ['../data/fold1\\94868-1-1-0.wav', 1],
#  ['../data/fold1\\94868-1-2-0.wav', 1],
#  ['../data/fold1\\96158-4-0-0.wav', 4],
#  ['../data/fold1\\97317-2-0-22.wav', 2],
#  ['../data/fold1\\97317-2-0-23.wav', 2],
#  ['../data/fold1\\97317-2-0-25.wav', 2],
#  ['../data/fold1\\97317-2-0-28.wav', 2],
#  ['../data/fold1\\97317-2-0-34.wav', 2],
#  ['../data/fold1\\97317-2-0-36.wav', 2],
#  ['../data/fold1\\97317-2-0-5.wav', 2],
#  ['../data/fold1\\98223-7-0-0.wav', 7],
#  ['../data/fold1\\98223-7-1-0.wav', 7],
#  ['../data/fold1\\98223-7-10-0.wav', 7],
#  ['../data/fold1\\98223-7-2-0.wav', 7],
#  ['../data/fold1\\98223-7-3-0.wav', 7],
#  ['../data/fold1\\98223-7-4-0.wav', 7],
#  ['../data/fold1\\98223-7-5-0.wav', 7],
#  ['../data/fold1\\98223-7-6-0.wav', 7],
#  ['../data/fold1\\98223-7-7-0.wav', 7],
#  ['../data/fold1\\98223-7-8-0.wav', 7],
#  ['../data/fold1\\98223-7-9-0.wav', 7],
#  ['../data/fold1\\99180-9-0-0.wav', 9],
#  ['../data/fold1\\99180-9-0-2.wav', 9],
#  ['../data/fold1\\99180-9-0-36.wav', 9],
#  ['../data/fold1\\99180-9-0-48.wav', 9],
#  ['../data/fold1\\99180-9-0-49.wav', 9],
#  ['../data/fold1\\99180-9-0-7.wav', 9],
#  ['../data/fold10\\100648-1-0-0.wav', 1],
#  ['../data/fold10\\100648-1-1-0.wav', 1],
#  ['../data/fold10\\100648-1-2-0.wav', 1],
#  ['../data/fold10\\100648-1-3-0.wav', 1],
#  ['../data/fold10\\100648-1-4-0.wav', 1],
#  ['../data/fold10\\100795-3-0-0.wav', 3],
#  ['../data/fold10\\100795-3-1-0.wav', 3],
#  ['../data/fold10\\100795-3-1-1.wav', 3],
#  ['../data/fold10\\100795-3-1-2.wav', 3],
#  ['../data/fold10\\101382-2-0-10.wav', 2],
#  ['../data/fold10\\101382-2-0-12.wav', 2],
#  ['../data/fold10\\101382-2-0-20.wav', 2],
#  ['../data/fold10\\101382-2-0-21.wav', 2],
#  ['../data/fold10\\101382-2-0-29.wav', 2],
#  ['../data/fold10\\101382-2-0-33.wav', 2],
#  ['../data/fold10\\101382-2-0-42.wav', 2],
#  ['../data/fold10\\101382-2-0-45.wav', 2],
#  ['../data/fold10\\102103-3-0-0.wav', 3],
#  ['../data/fold10\\102103-3-1-0.wav', 3],
#  ['../data/fold10\\102857-5-0-0.wav', 5],
#  ['../data/fold10\\102857-5-0-1.wav', 5],
#  ['../data/fold10\\102857-5-0-10.wav', 5],
#  ['../data/fold10\\102857-5-0-11.wav', 5],
#  ['../data/fold10\\102857-5-0-12.wav', 5],
#  ['../data/fold10\\102857-5-0-13.wav', 5],
#  ['../data/fold10\\102857-5-0-14.wav', 5],
#  ['../data/fold10\\102857-5-0-15.wav', 5],
#  ['../data/fold10\\102857-5-0-16.wav', 5],
#  ['../data/fold10\\102857-5-0-17.wav', 5],
#  ['../data/fold10\\102857-5-0-18.wav', 5],
#  ['../data/fold10\\102857-5-0-19.wav', 5],
#  ['../data/fold10\\102857-5-0-2.wav', 5],
#  ['../data/fold10\\102857-5-0-20.wav', 5],
#  ['../data/fold10\\102857-5-0-21.wav', 5],
#  ['../data/fold10\\102857-5-0-22.wav', 5],
#  ['../data/fold10\\102857-5-0-23.wav', 5],
#  ['../data/fold10\\102857-5-0-24.wav', 5],
#  ['../data/fold10\\102857-5-0-25.wav', 5],
#  ['../data/fold10\\102857-5-0-26.wav', 5],
#  ['../data/fold10\\102857-5-0-27.wav', 5],
#  ['../data/fold10\\102857-5-0-28.wav', 5],
#  ['../data/fold10\\102857-5-0-29.wav', 5],
#  ['../data/fold10\\102857-5-0-3.wav', 5],
#  ['../data/fold10\\102857-5-0-30.wav', 5],
#  ['../data/fold10\\102857-5-0-4.wav', 5],
#  ['../data/fold10\\102857-5-0-5.wav', 5],
#  ['../data/fold10\\102857-5-0-6.wav', 5],
#  ['../data/fold10\\102857-5-0-7.wav', 5],
#  ['../data/fold10\\102857-5-0-8.wav', 5],
#  ['../data/fold10\\102857-5-0-9.wav', 5],
#  ['../data/fold10\\103438-5-0-0.wav', 5],
#  ['../data/fold10\\103438-5-0-1.wav', 5],
#  ['../data/fold10\\103438-5-0-2.wav', 5],
#  ['../data/fold10\\106014-5-0-0.wav', 5],
#  ['../data/fold10\\106014-5-0-1.wav', 5],
#  ['../data/fold10\\106014-5-0-2.wav', 5],
#  ['../data/fold10\\106014-5-0-3.wav', 5],
#  ['../data/fold10\\106014-5-0-4.wav', 5],
#  ['../data/fold10\\115241-9-0-1.wav', 9],
#  ['../data/fold10\\115241-9-0-14.wav', 9],
#  ['../data/fold10\\115241-9-0-2.wav', 9],
#  ['../data/fold10\\115241-9-0-20.wav', 9],
#  ['../data/fold10\\115241-9-0-6.wav', 9],
#  ['../data/fold10\\115241-9-0-8.wav', 9],
#  ['../data/fold10\\115241-9-0-9.wav', 9],
#  ['../data/fold10\\115418-9-0-11.wav', 9],
#  ['../data/fold10\\115418-9-0-12.wav', 9],
#  ['../data/fold10\\115418-9-0-15.wav', 9],
#  ['../data/fold10\\115418-9-0-20.wav', 9],
#  ['../data/fold10\\115418-9-0-29.wav', 9],
#  ['../data/fold10\\115418-9-0-6.wav', 9],
#  ['../data/fold10\\11722-3-0-0.wav', 3],
#  ['../data/fold10\\11722-3-1-0.wav', 3],
#  ['../data/fold10\\117889-9-0-12.wav', 9],
#  ['../data/fold10\\117889-9-0-20.wav', 9],
#  ['../data/fold10\\117889-9-0-30.wav', 9],
#  ['../data/fold10\\117889-9-0-36.wav', 9],
#  ['../data/fold10\\117889-9-0-39.wav', 9],
#  ['../data/fold10\\117889-9-0-40.wav', 9],
#  ['../data/fold10\\118278-4-0-0.wav', 4],
#  ['../data/fold10\\118278-4-0-1.wav', 4],
#  ['../data/fold10\\118278-4-0-10.wav', 4],
#  ['../data/fold10\\118278-4-0-11.wav', 4],
#  ['../data/fold10\\118278-4-0-12.wav', 4],
#  ['../data/fold10\\118278-4-0-13.wav', 4],
#  ['../data/fold10\\118278-4-0-2.wav', 4],
#  ['../data/fold10\\118278-4-0-3.wav', 4],
#  ['../data/fold10\\118278-4-0-4.wav', 4],
#  ['../data/fold10\\118278-4-0-5.wav', 4],
#  ['../data/fold10\\118278-4-0-6.wav', 4],
#  ['../data/fold10\\118278-4-0-7.wav', 4],
#  ['../data/fold10\\118278-4-0-8.wav', 4],
#  ['../data/fold10\\118278-4-0-9.wav', 4],
#  ['../data/fold10\\118558-5-0-0.wav', 5],
#  ['../data/fold10\\118558-5-0-1.wav', 5],
#  ['../data/fold10\\118558-5-0-2.wav', 5],
#  ['../data/fold10\\118558-5-1-0.wav', 5],
#  ['../data/fold10\\118558-5-1-1.wav', 5],
#  ['../data/fold10\\118558-5-1-2.wav', 5],
#  ['../data/fold10\\118558-5-2-0.wav', 5],
#  ['../data/fold10\\118558-5-2-1.wav', 5],
#  ['../data/fold10\\118558-5-2-2.wav', 5],
#  ['../data/fold10\\118558-5-2-3.wav', 5],
#  ['../data/fold10\\119067-0-0-0.wav', 0],
#  ['../data/fold10\\119067-0-0-1.wav', 0],
#  ['../data/fold10\\119067-0-0-2.wav', 0],
#  ['../data/fold10\\128240-3-0-1.wav', 3],
#  ['../data/fold10\\128240-3-0-20.wav', 3],
#  ['../data/fold10\\128240-3-0-39.wav', 3],
#  ['../data/fold10\\128240-3-0-42.wav', 3],
#  ['../data/fold10\\128470-3-0-0.wav', 3],
#  ['../data/fold10\\128470-3-0-1.wav', 3],
#  ['../data/fold10\\128470-3-0-5.wav', 3],
#  ['../data/fold10\\128470-3-0-8.wav', 3],
#  ['../data/fold10\\129750-2-0-3.wav', 2],
#  ['../data/fold10\\129750-2-0-34.wav', 2],
#  ['../data/fold10\\129750-2-0-36.wav', 2],
#  ['../data/fold10\\129750-2-0-37.wav', 2],
#  ['../data/fold10\\129750-2-0-4.wav', 2],
#  ['../data/fold10\\129750-2-0-45.wav', 2],
#  ['../data/fold10\\129750-2-0-46.wav', 2],
#  ['../data/fold10\\129750-2-0-48.wav', 2],
#  ['../data/fold10\\136558-9-0-1.wav', 9],
#  ['../data/fold10\\136558-9-0-2.wav', 9],
#  ['../data/fold10\\136558-9-1-10.wav', 9],
#  ['../data/fold10\\136558-9-1-21.wav', 9],
#  ['../data/fold10\\136558-9-1-26.wav', 9],
#  ...]

# %%
from datacollector import DataCollector
metadata_path = "../data/UrbanSound8K.csv"

data_collector = DataCollector(fold_paths, metadata_path)

# Collect training data paths (from folds 0 to 8)
train_data_paths = data_collector.collect_data_paths(0, 9)

# Collect testing data paths (from folds 9 to 10)
test_data_paths = data_collector.collect_data_paths(9, 11)

data_paths = data_collector.collect_data_paths(0, 11)
# Out:
# 0.13971411784489948  mins
# 7022
# 0.03635719617207845  mins
# 1710
# 0.1735539436340332  mins
# 8732

# %%
features1 = {"ae_mean", "ae_var", "rms_mean", "rms_var", "zcr_mean", "zcr_var", "chroma_stft_mean", 
            "chroma_stft_var", "spec_centroid_mean", "spec_centroid_var", "spec_cont_mean", "spec_cont_var",
            "spec_bw_mean", "spec_bw,var","percep_mean", "percep_var", "tempo_mean", "tempo_var", 
            "roll_off_mean", "roll_off_var", "roll_off50_mean","roll_off50_var","roll_off25_mean","roll_off25_var",
            "log_mel_mean", "log_mel_var", "mfcc_mean", "mfcc_var", "spec_mean", "spec_var"}

len(features1)
# Out:
# 30

# %% [markdown]
# ## Extracting features from the Audio data

# %%
features_list = {"ae_mean":[], "ae_var":[], "rms_mean":[], "rms_var":[], "zcr_mean":[], "zcr_var":[], "chroma_stft_mean":[], 
            "chroma_stft_var":[], "spec_centroid_mean":[], "spec_centroid_var":[], "spec_cont_mean":[], "spec_cont_var":[],
            "spec_bw_mean":[], "spec_bw_var":[],"percep_mean":[], "percep_var":[], "tempo_mean":[], "tempo_var":[], 
            "roll_off_mean":[], "roll_off_var":[], "roll_off50_mean":[],"roll_off50_var":[],"roll_off25_mean":[],"roll_off25_var":[],
            "log_mel_mean":[], "log_mel_var":[], "mfcc_mean":[], "mfcc_var":[],"spec_mean":[], "spec_var":[], 
            "mag_spec_mean" :[] ,"mag_spec_var":[], "mel_mean":[], "mel_var":[]}

# %% [markdown]
# TODO add fuctions to the class

# %%
import numpy as np
import librosa
import IPython.display as ipd

FRAME_LENGTH = 2048
HOP_LENGTH = 512
FRAME_SIZE = 2048
HOP_SIZE = 512


def amplitude_envelope(signal, frame_size = 2048, hop_length = 512):
    amplitude_envelope = []
        
    for i in range(0, len(signal), hop_length):
        current_frame_amplitude_envelope = max(signal[i:i+frame_size])
        amplitude_envelope.append(current_frame_amplitude_envelope)
        
    return np.array(amplitude_envelope)

def Rms(song):
    rms_song = librosa.feature.rms(y = song, frame_length=FRAME_LENGTH, hop_length=HOP_LENGTH)
    return rms_song


def Zcr(song):
    zcr_song = librosa.feature.zero_crossing_rate(y = song, frame_length=FRAME_LENGTH, hop_length=HOP_LENGTH)
    return zcr_song

def Mag_spec(song):
    signal_ft = np.fft.fft(song)
    magnitude_spectrum = np.abs(signal_ft)
    return magnitude_spectrum
    
def spectrogram(song):
    song_stft = librosa.stft(song, n_fft=FRAME_SIZE, hop_length=HOP_SIZE)
    y_song = np.abs(song_stft)**2
    return y_song

def log_spec(song):    
    spec_song = spectrogram(song)
    y_song_log = librosa.power_to_db(spec_song)

def log_mel(song, samp_rate):
    mel_spectrogram = librosa.feature.melspectrogram(y = song, n_fft= 2048, sr = samp_rate, hop_length = 512 ,n_mels=50)
    log_mel_spectrogram = librosa.power_to_db(mel_spectrogram)
    return log_mel_spectrogram

def Mfcc(song, samp_rate, nmfcc = 13):
    mfccs = librosa.feature.mfcc(y = song, n_mfcc= nmfcc, sr = samp_rate)
    return mfccs

def delta_mfcc(song, samp_rate, nmfcc = 13):
    mfccs = Mfcc(song,samp_rate)
    delta_mfcc = librosa.feature.delta(mfccs)
    delta2_mfcc = librosa.feature.delta(mfccs, order=2)
    delta3_mfcc = librosa.feature.delta(mfccs, order=3)
    delta4_mfcc = librosa.feature.delta(mfccs, order=4)
    delta5_mfcc = librosa.feature.delta(mfccs, order=5)
    delta6_mfcc = librosa.feature.delta(mfccs, order=6)

    return (delta_mfcc, delta2_mfcc, delta3_mfcc, delta4_mfcc, delta5_mfcc, delta6_mfcc)

def Chroma_stft(song, samp_rate):  
    c_stft = librosa.feature.chroma_stft(y = song,sr = samp_rate)
    return c_stft

def Spec_centriod(song, samp_rate):
    return librosa.feature.spectral_centroid(y = song,sr = samp_rate)

# spectral rolloff is the frequency below which a specified percentage of the total spectral energy, e.g. 85%, lies.
def spec_roll_off(song, samp_rate):
    return librosa.feature.spectral_rolloff(y = song, sr =samp_rate)

def spec_roll_off50(song, samp_rate):
    return librosa.feature.spectral_rolloff(y = song, sr= samp_rate, roll_percent=0.5)

def spec_roll_off25(song, samp_rate):
    return librosa.feature.spectral_rolloff(y = song,sr = samp_rate, roll_percent=0.25)

def spec_contrast(song, samp_rate):
    return librosa.feature.spectral_contrast(y = song,sr = samp_rate)

def perceptual_wt(song, samp_rate):
    return librosa.perceptual_weighting(S = song)

def tempogram(song, samp_rate):
    return librosa.feature.tempogram(y = song, sr = samp_rate)

def spec_bandwidth(song, samp_rate):
    return librosa.feature.spectral_bandwidth(y = song, sr = samp_rate)

# %%
s = time.time()

for i in range(len(data_paths)):
    
    sample , sr = librosa.load(data_paths[i][0])
    
    
    ae = amplitude_envelope(sample, frame_size = 2048, hop_length = 512)
    ae_m, ae_v = ae.mean(), ae.var()
    features_list["ae_mean"].append(ae_m)
    features_list["ae_var"].append(ae_v)
    
    
    rms = Rms(sample)
    rms_m, rms_v = rms.mean(), rms.var()
    features_list["rms_mean"].append(rms_m)
    features_list["rms_var"].append(rms_v)
    
    zcr =  Zcr(sample)
    zcr_m, zcr_v = zcr.mean(), zcr.var()
    features_list["zcr_mean"].append(zcr_m)
    features_list['zcr_var'].append(zcr_v)
    
    
    mag_spec = Mag_spec(sample)
    features_list["mag_spec_mean"].append(mag_spec.mean())
    features_list["mag_spec_var"].append(mag_spec.var())
    
    
    spec = spectrogram(sample)
    features_list["spec_mean"].append(spec.mean())
    features_list['spec_var'].append(spec.var())
    
    
    mel_spec = log_mel(sample, sr)
    features_list["mel_mean"].append(mel_spec.mean())
    features_list["mel_var"].append(mel_spec.var())
    
    
    mfcc = Mfcc(sample, sr)
    features_list["mfcc_mean"].append(mfcc.mean())
    features_list["mfcc_var"].append(mfcc.var())
    
            
    chroma_stft = Chroma_stft(sample, sr)
    features_list["chroma_stft_mean"].append(chroma_stft.mean())
    features_list['chroma_stft_var'].append(chroma_stft.var())
    
    spec_centriod = Spec_centriod(sample, sr)
    features_list['spec_centroid_mean'].append(spec_centriod.mean())
    features_list['spec_centroid_var'].append(spec_centriod.var())
    
    
    spec_roll = spec_roll_off(sample, sr)
    features_list["roll_off_mean"].append(spec_roll.mean())
    features_list['roll_off_var'].append(spec_roll.var())
    
    
    spec_roll50 = spec_roll_off50(sample, sr)
    features_list["roll_off50_mean"].append(spec_roll50.mean())
    features_list['roll_off50_var'].append(spec_roll50.var())
    
    
    spec_roll25 =  spec_roll_off25(sample, sr)
    features_list["roll_off25_mean"].append(spec_roll25.mean())
    features_list['roll_off25_var'].append(spec_roll25.var())
    
    
    spec_contr =  spec_contrast(sample, sr)
    features_list["spec_cont_mean"].append(spec_contr.mean())
    features_list['spec_cont_var'].append(spec_contr.var())
    

#     percep =  perceptual_wt(sample, sr)
#     features_list["percep_mean"].append(percep.mean())
#     features_list['percep_var'].append(percep.var())
    
    
    tempo =  tempogram(sample, sr)
    features_list["tempo_mean"].append(tempo.mean())
    features_list["tempo_var"].append(tempo.var())
    
    
    spec_bw =  spec_bandwidth(sample, sr)
    features_list["spec_bw_mean"].append(spec_bw.mean())
    features_list['spec_bw_var'].append(spec_bw.var())
    
    log_me = log_mel(sample, sr)
    features_list["log_mel_mean"].append(log_me.mean())
    features_list['log_mel_var'].append(log_me.var())
    
#     print(i)

    
e = time.time()
print((e - s)/60  , "mins")
# Out:
# c:\Users\ozkan\Desktop\MSc.DataScience\Machine Learning\FinalProject\venv\Lib\site-packages\librosa\core\pitch.py:102: UserWarning: Trying to estimate tuning from empty frequency set.
#   return pitch_tuning(
# c:\Users\ozkan\Desktop\MSc.DataScience\Machine Learning\FinalProject\venv\Lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=2048 is too large for input signal of length=1323
#   warnings.warn(
# c:\Users\ozkan\Desktop\MSc.DataScience\Machine Learning\FinalProject\venv\Lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=2048 is too large for input signal of length=1103
#   warnings.warn(
# c:\Users\ozkan\Desktop\MSc.DataScience\Machine Learning\FinalProject\venv\Lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=2048 is too large for input signal of length=1523
#   warnings.warn(
# 28.614593732357026 mins

# %%
print(len(features_list))
# Out:
# 34

# %%
del features_list["percep_mean"]
del features_list["percep_var"]

# %%
feature_df = pd.DataFrame(features_list)
feature_df
# Out:
#        ae_mean    ae_var  rms_mean   rms_var  zcr_mean   zcr_var  \
# 0     0.149282  0.014686  0.036457  0.000857  0.258637  0.005267
# 1     0.347395  0.017407  0.100865  0.001697  0.218753  0.004286
# 2     0.195377  0.016779  0.050473  0.000908  0.226105  0.002822
# 3     0.203674  0.003955  0.058281  0.000223  0.154624  0.001250
# 4     0.142380  0.001004  0.042241  0.000080  0.124026  0.000784
# ...        ...       ...       ...       ...       ...       ...
# 8727  0.184060  0.016045  0.045473  0.000786  0.402863  0.009161
# 8728  0.226428  0.009619  0.065369  0.000740  0.364969  0.010937
# 8729  0.209352  0.006634  0.063438  0.000710  0.292946  0.006543
# 8730  0.195731  0.010443  0.055393  0.000848  0.297239  0.006732
# 8731  0.192785  0.011244  0.048012  0.000519  0.352610  0.008454
#
#       chroma_stft_mean  chroma_stft_var  spec_centroid_mean  \
# 0             0.559152         0.059094         3574.630967
# 1             0.534395         0.072700         3289.877463
# 2             0.544626         0.072916         3194.741895
# 3             0.625679         0.048116         2945.500877
# 4             0.507904         0.074726         2541.069048
# ...                ...              ...                 ...
# 8727          0.526332         0.070463         4537.477572
# 8728          0.510395         0.063308         4208.264715
# 8729          0.546787         0.056688         3829.861053
# 8730          0.586017         0.054295         3885.937356
# 8731          0.557228         0.059620         4362.593373
#
#       spec_centroid_var  ...  log_mel_mean  log_mel_var  mfcc_mean  \
# 0         413446.432939  ...    -15.533721   119.464134 -18.431484
# 1         327178.108834  ...     -4.988582    66.677063 -11.099107
# 2         223225.384307  ...    -11.599207    76.346642 -15.194706
# 3         131307.204614  ...     -7.788991    59.251881  -4.159441
# 4          76634.671213  ...    -11.885075    78.149147  -6.330313
# ...                 ...  ...           ...          ...        ...
# 8727      286603.811113  ...    -11.485449    49.542812 -17.651739
# 8728      389370.298246  ...     -8.368240    60.312012 -15.366465
# 8729      266074.687371  ...     -8.635166    70.379433 -15.943607
# 8730      191547.448804  ...     -9.940153    71.772781 -17.681288
# 8731      365824.083912  ...    -10.634192    60.345760 -19.706751
#
#          mfcc_var  spec_mean     spec_var  mag_spec_mean  mag_spec_var  \
# 0     3430.470947   1.687729   123.678757       9.960397     95.902847
# 1      829.579590   9.126315  6474.970703      19.361811    679.211071
# 2     2013.253418   2.667969   703.012329      10.952194    188.635973
# 3     1231.435791   2.805299   916.879822      10.660433    208.096372
# 4     2223.590820   1.441622   127.031258       6.929858    117.666083
# ...           ...        ...          ...            ...           ...
# 8727  1690.843506   2.191361   289.115906      10.229035    148.404577
# 8728  1217.042114   3.864394   582.782593      12.551192    289.233965
# 8729  1351.653564   3.635856   482.065735      11.390014    290.117826
# 8730  1569.002075   3.018281   350.575043      10.788252    232.454590
# 8731  1571.625000   2.168980   111.228516      10.253757    145.325221
#
#        mel_mean     mel_var
# 0    -15.533721  119.464134
# 1     -4.988582   66.677063
# 2    -11.599207   76.346642
# 3     -7.788991   59.251881
# 4    -11.885075   78.149147
# ...         ...         ...
# 8727 -11.485449   49.542812
# 8728  -8.368240   60.312012
# 8729  -8.635166   70.379433
# 8730  -9.940153   71.772781
# 8731 -10.634192   60.345760
#
# [8732 rows x 32 columns]

# %%
feature_df.to_csv("../data/output/features.csv", index = False)
